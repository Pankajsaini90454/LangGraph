# %%
from langgraph.graph import StateGraph,START,END
#from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv
from langchain_ollama  import ChatOllama

# %%
load_dotenv()
# Out:
# False

# %%
#model=ChatOpenAI()
model=ChatOllama(model="llama3.2")

# %%
class BlogState(TypedDict):
    title:str
    outline:str
    content:str

# %%
def create_outline(state:BlogState)->BlogState:
    #fetch title
    title=state['title']
    #call llm gen outline
    prompt=f'generate a detailed outline for a blog on the topic-{title}'
    outline=model.invoke(prompt).content
    #update state
    state['outline']=outline
    return state

# %%
def create_blog(state:BlogState)->BlogState:
    title=state['title']
    outline=state['outline']
    prompt=f'write a detailed blog on the title-{title} using the following outlinr\n {outline}'
    content=model.invoke(prompt).content
    state['content']=content
    return state

# %%
graph=StateGraph(BlogState)

graph.add_node('create_outline',create_outline)
graph.add_node('create_blog',create_blog)

graph.add_edge(START,'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog',END)
workflow =graph.compile()

# %%
initial_state={'title':'Rise of AI in India'}

final_state=workflow.invoke(initial_state)
print(final_state['outline'])
# Out:
# Here is a detailed outline for a blog on the "Rise of AI in India":
#
# **I. Introduction**
#
# * Brief overview of the rapid growth of Artificial Intelligence (AI) globally
# * Importance of AI in India's economic and social development
# * Thesis statement: India is witnessing a significant rise in AI adoption, driven by government initiatives, technological advancements, and changing business needs.
#
# **II. Government Initiatives and Policies**
#
# * Overview of key government initiatives and policies supporting AI in India
# * Examples:
#  + Make in India initiative
#  + Startup India program
#  + Digital India mission
#  + Skill India program
# * Discussion on the role of government in fostering AI adoption in India
#
# **III. Technological Advancements**
#
# * Overview of AI technologies being adopted in India
# * Examples:
#  + Machine Learning (ML) and Deep Learning (DL)
#  + Natural Language Processing (NLP)
#  + Computer Vision
#  + Robotic Process Automation (RPA)
# * Discussion on the impact of technological advancements on AI adoption in India
#
# **IV. Business Adoption and Use Cases**
#
# * Examples of businesses adopting AI in India
# * Use cases:
#  + Healthcare: AI-powered diagnosis and treatment
#  + Finance: AI-driven risk management and customer service
#  + Retail: AI-powered chatbots and recommendation engines
#  + Manufacturing: AI-based quality control and supply chain management
# * Discussion on the benefits and challenges of AI adoption in Indian businesses
#
# **V. Education and Training**
#
# * Overview of AI-related education and training programs in India
# * Examples:
#  + AI and Machine Learning courses at Indian Institutes of Technology (IITs)
#  + AI-focused startups and incubators
#  + Online courses and certification programs
# * Discussion on the need for a skilled workforce in AI and its impact on the Indian economy
#
# **VI. Challenges and Concerns**
#
# * Discussion on the challenges and concerns related to AI adoption in India
# * Examples:
#  + Data security and privacy concerns
#  + Job displacement and skill obsolescence
#  + Bias and fairness in AI decision-making
#  + Regulatory and governance issues
# * Discussion on the need for a balanced approach to AI adoption
#
# **VII. Conclusion**
#
# * Recap of the rise of AI in India
# * Discussion on the future of AI in India and its potential to drive economic growth and social development
# * Final thoughts on the importance of responsible AI adoption in India
#
# **VIII. References**
#
# * List of sources used in the blog post, including government reports, industry publications, and academic research.
#
# This outline provides a comprehensive structure for a blog post on the rise of AI in India, covering government initiatives, technological advancements, business adoption, education, challenges, and concerns.
